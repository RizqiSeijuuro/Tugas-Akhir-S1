# %% [markdown]
# # 1. Import

# %%
# Import Library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import Data
df = pd.read_csv('https://raw.githubusercontent.com/RizqiSeijuuro/Tugas-Akhir-S1/main/Data%20Penelitian%20TA/Konsistensi.csv', sep=',')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,1,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                 TIME    Date     Time2  Intensity  UV Index  Voltage
# 0        21:59:56.78  5/7/22  22:03:56        0.0       0.0      0.0
# 1        21:59:57.85  5/7/22  22:03:57        0.0       0.0      0.0
# 2        21:59:58.92  5/7/22  22:03:58        0.0       0.0      0.0
# 3        22:00:00.00  5/7/22  22:03:59        0.0       0.0      0.0
# 4        22:00:01.07  5/7/22  22:04:00        0.0       0.0      0.0
# ...              ...     ...       ...        ...       ...      ...
# 1000001          NaN     NaN       NaN        NaN       NaN      NaN
# 1000002          NaN     NaN       NaN        NaN       NaN      NaN
# 1000003          NaN     NaN       NaN        NaN       NaN      NaN
# ...

# %% [markdown]
# # 2. Data Understanding

# %%
# Read DataFrame
df.describe()
# Out:
#          Intensity  UV Index      Voltage
# count  7158.000000    7158.0  7158.000000
# mean      0.073054       0.0     0.048086
# std       0.006451       0.0     0.005117
# min       0.000000       0.0     0.000000
# 25%       0.070000       0.0     0.050000
# 50%       0.070000       0.0     0.050000
# 75%       0.080000       0.0     0.050000
# max       0.090000       0.0     0.060000

# %% [markdown]
# ## 2.1. Data Preparation

# %%
# Drop Missing Values & Change data type to datetime
df = df.dropna()
df['Date'] = pd.to_datetime(df['Date'])
pd.to_datetime(df['Time2'], format='%H:%M:%S')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0      1900-01-01 22:03:56
# 1      1900-01-01 22:03:57
# 2      1900-01-01 22:03:58
# 3      1900-01-01 22:03:59
# 4      1900-01-01 22:04:00
#                ...
# 7153   1900-01-01 00:10:06
# 7154   1900-01-01 00:10:07
# 7155   1900-01-01 00:10:08
# 7156   1900-01-01 00:10:09
# 7157   1900-01-01 00:10:10
# Name: Time2, Length: 7158, dtype: datetime64[ns]

# %%
df
# Out:
#              TIME       Date     Time2  Intensity  UV Index  Voltage
# 0     21:59:56.78 2022-05-07  22:03:56       0.00       0.0     0.00
# 1     21:59:57.85 2022-05-07  22:03:57       0.00       0.0     0.00
# 2     21:59:58.92 2022-05-07  22:03:58       0.00       0.0     0.00
# 3     22:00:00.00 2022-05-07  22:03:59       0.00       0.0     0.00
# 4     22:00:01.07 2022-05-07  22:04:00       0.00       0.0     0.00
# ...           ...        ...       ...        ...       ...      ...
# 7153   0:06:06.50 2022-06-07   0:10:06       0.07       0.0     0.05
# 7154   0:06:07.53 2022-06-07   0:10:07       0.07       0.0     0.05
# 7155   0:06:08.57 2022-06-07   0:10:08       0.08       0.0     0.05
# 7156   0:06:09.64 2022-06-07   0:10:09       0.09       0.0     0.06
# 7157   0:06:10.72 2022-06-07   0:10:10       0.08       0.0     0.05
#
# [7158 rows x 6 columns]

# %% [markdown]
# # 3. Data Visualization

# %%
# Create Data Visualization
fig, ax = plt.subplots(figsize=(18, 8), dpi=216)
plt.title("Uji Konsistensi Lampu UV", fontsize=22, y=1.05)
plt.xlabel('Detik ke', fontsize='18')
plt.yticks(fontsize='14')
plt.ylabel(r'$ Intensitas \quad UV \quad (\frac{mW}{cm^2})$', fontsize='18')
ax.plot(df.index, df['Intensity'], linewidth=1.1, alpha=0.9)
